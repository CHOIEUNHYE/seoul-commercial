# %%
import os
import csv

file_path = os.path.join(os.path.join('uploads', 'seoul_commercial_district.csv'))
result = []

with open(file_path, 'r') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        if row['상호명'] == '토끼정':
           result.append(row)

# %%
result
# Out:
# [{'상가업소번호': 'MA010120220805430767',
#   '상호명': '토끼정',
#   '지점명': '',
#   '상권업종대분류코드': 'I2',
#   '상권업종대분류명': '음식',
#   '상권업종중분류코드': 'I201',
#   '상권업종중분류명': '한식',
#   '상권업종소분류코드': 'I20101',
#   '상권업종소분류명': '백반/한정식',
#   '표준산업분류코드': 'I56111',
#   '표준산업분류명': '한식 일반 음식점업',
#   '시도코드': '11',
#   '시도명': '서울특별시',
#   '시군구코드': '11500',
#   '시군구명': '강서구',
#   '행정동코드': '11500603',
#   '행정동명': '가양1동',
#   '법정동코드': '1150010500',
#   '법정동명': '마곡동',
#   '지번코드': '1150010500107740012',
#   '대지구분코드': '1',
#   '대지구분명': '대지',
#   '지번본번지': '774',
#   '지번부번지': '12',
#   '지번주소': '서울특별시 강서구 마곡동 774-12',
#   '도로명코드': '115003155046',
#   '도로명': '서울특별시 강서구 마곡동로',
#   '건물본번지': '55',
#   '건물부번지': '',
#   '건물관리번호': '1150010500107740012000001',
#   '건물명': '마커스빌딩',
#   '도로명주소': '서울특별시 강서구 마곡동로 55',
#   '구우편번호': '157805',
#   '신우편번호': '07802',
#   '동정보': '',
#   '층정보': '2',
#   '호정보': '',
#   '경도': '126.833021682981',
#   '위도': '37.5600534290077'},
#  {'상가업소번호': 'MA010120220808514422',
#   '상호명': '토끼정',
#   '지점명': '',
#   '상권업종대분류코드': 'I2',
#   '상권업종대분류명': '음식',
#   '상권업종중분류코드': 'I201',
#   '상권업종중분류명': '한식',
#   '상권업종소분류코드': 'I20101',
#   '상권업종소분류명': '백반/한정식',
#   '표준산업분류코드': 'I56111',
#   '표준산업분류명': '한식 일반 음식점업',
#   '시도코드': '11',
#   '시도명': '서울특별시',
#   '시군구코드': '11110',
#   '시군구명': '종로구',
#   '행정동코드': '11110640',
#   '행정동명': '이화동',
#   '법정동코드': '1111016800',
#   '법정동명': '동숭동',
#   '지번코드': '1111016800100010132',
#   '대지구분코드': '1',
#   '대지구분명': '대지',
#   '지번본번지': '1',
#   '지번부번지': '132',
#   '지번주소': '서울특별시 종로구 동숭동 1-132',
#   '도로명코드': '111104100043',
#   '도로명': '서울특별시 종로구 대학로8가길',
#   '건물본번지': '133',
#   '건물부번지': '',
#   '건물관리번호': '1111016800100010132010506',
#   '건물명': '',
#   '도로명주소': '서울특별시 종로구 대학로8가길 133',
#   '구우편번호': '110809',
#   '신우편번호': '03086',
#   '동정보': '',
#   '층정보': '2',
#   '호정보': '',
#   '경도': '127.003506042591',
#   '위도': '37.5801139136701'},
#  {'상가업소번호': 'MA010120220809755675',
#   '상호명': '토끼정',
#   '지점명': '',
#   '상권업종대분류코드': 'I2',
#   '상권업종대분류명': '음식',
#   '상권업종중분류코드': 'I201',
#   '상권업종중분류명': '한식',
#   '상권업종소분류코드': 'I20101',
#   '상권업종소분류명': '백반/한정식',
#   '표준산업분류코드': 'I56111',
#   '표준산업분류명': '한식 일반 음식점업',
#   '시도코드': '11',
#   '시도명': '서울특별시',
#   '시군구코드': '11440',
#   '시군구명': '마포구',
#   '행정동코드': '11440660',
#   '행정동명': '서교동',
#   '법정동코드': '1144012000',
#   '법정동명': '서교동',
#   '지번코드': '1144012000103660004',
#   '대지구분코드': '1',
#   '대지구분명': '대지',
#   '지번본번지': '366',
#   '지번부번지': '4',
#   '지번주소': '서울특별시 마포구 서교동 366-4',
#   '도로명코드': '114404139569',
#   '도로명': '서울특별시 마포구 잔다리로2길',
#   '건물본번지': '13',
#   '건물부번지': '',
#   '건물관리번호': '1144012000103660004010338',
#   '건물명': '',
#   '도로명주소': '서울특별시 마포구 잔다리로2길 13',
#   '구우편번호': '121893',
#   '신우편번호': '04042',
#   '동정보': '',
#   '층정보': '1',
#   '호정보': '',
#   '경도': '126.920679422698',
#   '위도': '37.5517057710031'}]

# %%
file_path = os.path.join(os.path.join('uploads', 'seoul_commercial_district.csv'))
result = []

with open(file_path, 'r') as file:
        csv_reader = csv.DictReader(file)
        headers = next(csv_reader)
        for row in csv_reader:
            if row['상호명'] == "토끼정":
                result.append(dict(zip(headers, row)))
result
# Out:
# [{'상가업소번호': '상가업소번호',
#   '상호명': '상호명',
#   '지점명': '지점명',
#   '상권업종대분류코드': '상권업종대분류코드',
#   '상권업종대분류명': '상권업종대분류명',
#   '상권업종중분류코드': '상권업종중분류코드',
#   '상권업종중분류명': '상권업종중분류명',
#   '상권업종소분류코드': '상권업종소분류코드',
#   '상권업종소분류명': '상권업종소분류명',
#   '표준산업분류코드': '표준산업분류코드',
#   '표준산업분류명': '표준산업분류명',
#   '시도코드': '시도코드',
#   '시도명': '시도명',
#   '시군구코드': '시군구코드',
#   '시군구명': '시군구명',
#   '행정동코드': '행정동코드',
#   '행정동명': '행정동명',
#   '법정동코드': '법정동코드',
#   '법정동명': '법정동명',
#   '지번코드': '지번코드',
#   '대지구분코드': '대지구분코드',
#   '대지구분명': '대지구분명',
#   '지번본번지': '지번본번지',
#   '지번부번지': '지번부번지',
#   '지번주소': '지번주소',
#   '도로명코드': '도로명코드',
#   '도로명': '도로명',
#   '건물본번지': '건물본번지',
#   '건물부번지': '건물부번지',
#   '건물관리번호': '건물관리번호',
#   '건물명': '건물명',
#   '도로명주소': '도로명주소',
#   '구우편번호': '구우편번호',
#   '신우편번호': '신우편번호',
#   '동정보': '동정보',
#   '층정보': '층정보',
#   '호정보': '호정보',
#   '경도': '경도',
#   '위도': '위도'},
#  {'상가업소번호': '상가업소번호',
#   '상호명': '상호명',
#   '지점명': '지점명',
#   '상권업종대분류코드': '상권업종대분류코드',
#   '상권업종대분류명': '상권업종대분류명',
#   '상권업종중분류코드': '상권업종중분류코드',
#   '상권업종중분류명': '상권업종중분류명',
#   '상권업종소분류코드': '상권업종소분류코드',
#   '상권업종소분류명': '상권업종소분류명',
#   '표준산업분류코드': '표준산업분류코드',
#   '표준산업분류명': '표준산업분류명',
#   '시도코드': '시도코드',
#   '시도명': '시도명',
#   '시군구코드': '시군구코드',
#   '시군구명': '시군구명',
#   '행정동코드': '행정동코드',
#   '행정동명': '행정동명',
#   '법정동코드': '법정동코드',
#   '법정동명': '법정동명',
#   '지번코드': '지번코드',
#   '대지구분코드': '대지구분코드',
#   '대지구분명': '대지구분명',
#   '지번본번지': '지번본번지',
#   '지번부번지': '지번부번지',
#   '지번주소': '지번주소',
#   '도로명코드': '도로명코드',
#   '도로명': '도로명',
#   '건물본번지': '건물본번지',
#   '건물부번지': '건물부번지',
#   '건물관리번호': '건물관리번호',
#   '건물명': '건물명',
#   '도로명주소': '도로명주소',
#   '구우편번호': '구우편번호',
#   '신우편번호': '신우편번호',
#   '동정보': '동정보',
#   '층정보': '층정보',
#   '호정보': '호정보',
#   '경도': '경도',
#   '위도': '위도'},
#  {'상가업소번호': '상가업소번호',
#   '상호명': '상호명',
#   '지점명': '지점명',
#   '상권업종대분류코드': '상권업종대분류코드',
#   '상권업종대분류명': '상권업종대분류명',
#   '상권업종중분류코드': '상권업종중분류코드',
#   '상권업종중분류명': '상권업종중분류명',
#   '상권업종소분류코드': '상권업종소분류코드',
#   '상권업종소분류명': '상권업종소분류명',
#   '표준산업분류코드': '표준산업분류코드',
#   '표준산업분류명': '표준산업분류명',
#   '시도코드': '시도코드',
#   '시도명': '시도명',
#   '시군구코드': '시군구코드',
#   '시군구명': '시군구명',
#   '행정동코드': '행정동코드',
#   '행정동명': '행정동명',
#   '법정동코드': '법정동코드',
#   '법정동명': '법정동명',
#   '지번코드': '지번코드',
#   '대지구분코드': '대지구분코드',
#   '대지구분명': '대지구분명',
#   '지번본번지': '지번본번지',
#   '지번부번지': '지번부번지',
#   '지번주소': '지번주소',
#   '도로명코드': '도로명코드',
#   '도로명': '도로명',
#   '건물본번지': '건물본번지',
#   '건물부번지': '건물부번지',
#   '건물관리번호': '건물관리번호',
#   '건물명': '건물명',
#   '도로명주소': '도로명주소',
#   '구우편번호': '구우편번호',
#   '신우편번호': '신우편번호',
#   '동정보': '동정보',
#   '층정보': '층정보',
#   '호정보': '호정보',
#   '경도': '경도',
#   '위도': '위도'}]

# %%
import pandas as pd
file_path = os.path.join(os.path.join('uploads', 'seoul_commercial_district.csv'))
result = []

df = pd.read_csv(file_path,encoding="cp949")
category_df = df.loc[df["상권업종대분류명"]=='소매']
city_county_count = category_df.groupby(by='시군구명').count()['상호명']

# %%
category_df.groupby(by='시군구명').count()[['상호명']].to_dict
# Out:
# <bound method DataFrame.to_dict of        상호명
# 시군구명
# 강남구   8723
# 강동구   4042
# 강북구   2751
# 강서구   4977
# 관악구   3720
# 광진구   3908
# 구로구   4043
# 금천구   3309
# 노원구   3414
# 도봉구   2226
# 동대문구  4206
# 동작구   2439
# 마포구   4120
# 서대문구  2699
# 서초구   5872
# 성동구   2844
# 성북구   3241
# 송파구   6576
# 양천구   3316
# 영등포구  5081
# 용산구   3721
# 은평구   3516
# 종로구   5136
# 중구    7375
# 중랑구   3310>

# %%
df.loc[df["상권업종대분류명"]=='소매']
# Out:
#                       상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 8       MA010120220805430834  무지개삼성약국  NaN        G2       소매      G215
# 14      MA010120220805430969      다이앤  NaN        G2       소매      G209
# 16      MA010120220805431087       해치  NaN        G2       소매      G215
# 20      MA010120220805431304    엠밸리스넥  NaN        G2       소매      G204
# 23      MA010120220805431385    누리봄약초  NaN        G2       소매      G205
# ...                      ...      ...  ...       ...      ...       ...
# 474228  MA0101202302A0004776  지에스25고척  제일점        G2       소매      G204
# 474233  MA0101202302A0083358       만성  NaN        G2       소매      G222
# 474242  MA0101202302A0107442    킹마트삼성  NaN        G2       소매      G205
# 474251  MA0101202302A0050062     신사답게  NaN        G2       소매      G209
# 474259  MA0101202302A0109595     송죽상회  NaN        G2       소매      G205
#
#            상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...  \
# 8         의약·화장품 소매    G21501          약국   G47811  ...
# 14      섬유·의복·신발 소매    G20902   여성 의류 소매업   G47412  ...
# 16        의약·화장품 소매    G21503     화장품 소매업   G47813  ...
# 20            종합 소매    G20404        슈퍼마켓   G47129  ...
# 23           식료품 소매    G20509  반찬/식료품 소매업   G47218  ...
# ...             ...       ...         ...      ...  ...
# 474228        종합 소매    G20405         편의점   G47122  ...
# 474233     중고 상품 소매    G22201   중고 상품 소매업   G47861  ...
# 474242       식료품 소매    G20503         정육점   G47212  ...
# 474251  섬유·의복·신발 소매    G20902   여성 의류 소매업   G47412  ...
# 474259       식료품 소매    G20504  건어물/젓갈 소매업   G47213  ...
#
#                            건물관리번호            건물명                도로명주소   구우편번호  \
# 8       1168011400106840005002734           대훈빌딩     서울특별시 강남구 일원로 45  135516
# 14      1114016200107750000009546         제일평화시장      서울특별시 중구 마장로 13  100837
# 16      1159010900106920006002347            NaN   서울특별시 동작구 신대방3길 25  156854
# 20      1150010500103890000000004       마곡엠밸리7단지   서울특별시 강서구 마곡서로 133  157855
# 23      1123010300109630000031509            NaN  서울특별시 동대문구 약령중앙로 42  130864
# ...                           ...            ...                  ...     ...
# 474228  1153010600101720078012234            NaN     서울특별시 구로구 경서로 83  152831
# 474233  1123010500109610009020285            NaN   서울특별시 동대문구 고미술로 99  130809
# 474242  1168010500100200005015150  강남대학교청담카이로스빌딩  서울특별시 강남구 삼성로119길 8  135508
# 474251  1156010400100310000000001     영등포시장지하도상가  서울특별시 영등포구 영등포로 221  150030
# 474259  1114015100100760001012670            NaN   서울특별시 중구 을지로 230-1  100195
#
#        신우편번호  동정보  층정보  호정보          경도         위도
# 8       6343  NaN  NaN  NaN  127.081499  37.489893
# 14      4567  NaN    1  NaN  127.011381  37.568503
# 16      7070  NaN    1  NaN  126.910341  37.487538
# 20      7798  NaN    1  NaN  126.823817  37.564548
# 23      2570  NaN  NaN  NaN  127.037356  37.582008
# ...      ...  ...  ...  ...         ...        ...
# 474228  8228  NaN    1  NaN  126.860834  37.504109
# 474233  2622  NaN  NaN  NaN  127.057973  37.564108
# 474242  6091  NaN    1  NaN  127.050622  37.516230
# 474251  7250  NaN  NaN  NaN  126.906038  37.519710
# 474259  4561  NaN    3  NaN  127.003676  37.566546
#
# [104565 rows x 39 columns]

# %%
df['상권업종대분류명'].unique()
# Out:
# array(['음식', '숙박', '교육', '과학·기술', '소매', '시설관리·임대', '수리·개인', '부동산',
#        '예술·스포츠', '보건의료'], dtype=object)
